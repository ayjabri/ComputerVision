# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Fri Jan 24 19:57:27 2020

@author: aymanjabri
Classify one of the MNIST datasets with adaptive learning rate, run multiple 
batch sizes and learning rates and other hyper parameters
"""
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision as tv
from torchvision import transforms,datasets,models
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.tensorboard import SummaryWriter
from collections import Counter,OrderedDict,namedtuple
from itertools import product

# %%
#GPU
if torch.cuda.is_available():
    device=torch.device('cuda:0')
else:
    device=torch.device('cpu')

# %%
#Transforms
tfms = transforms.Compose([transforms.ToTensor(),
                           transforms.Normalize((0.5,),(0.5,))])
#Download data into datasets
trns = datasets.MNIST('.',train=True,transform=
                    tfms,download=True)
tsts = datasets.MNIST('.',train=False,transform=
                    tfms,download=True)
#check for datasets imbalance:
# print(sorted(Counter(trns.targets.numpy()).items()))
# print(sorted(Counter(tsts.targets.numpy()).items()))

#Combine test and training datasets
ds = torch.utils.data.ConcatDataset((trns,tsts))

#Split training and validation sets
trainset,validset = torch.utils.data.random_split(ds,[50000,20000])

train = torch.utils.data.DataLoader(trainset,batch_size=100,shuffle=True)
valid = torch.utils.data.DataLoader(validset,batch_size=500)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./MNIST/raw/train-images-idx3-ubyte.gz
# 0it [00:00, ?it/s]
# Extracting ./MNIST/raw/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./MNIST/raw/train-labels-idx1-ubyte.gz
# 0it [00:00, ?it/s]
# Extracting ./MNIST/raw/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./MNIST/raw/t10k-images-idx3-ubyte.gz
# 0it [00:00, ?it/s]
# Extracting ./MNIST/raw/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./MNIST/raw/t10k-labels-idx1-ubyte.gz
# 0it [00:00, ?it/s]
# Extracting ./MNIST/raw/t10k-labels-idx1-ubyte.gz
# Processing...
# Done!
# /home/ayman/anaconda3/envs/dqn/lib/python3.8/site-packages/torchvision/datasets/mnist.py:335: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1616554793803/work/torch/csrc/utils/tensor_numpy.cpp:143.)
#   return torch.from_numpy(parsed).view(length, num_rows, num_cols)

# %%
#view the data
img,label = next(iter(train))
imgs = tv.utils.make_grid(img,nrow=10,padding=1,normalize=True)
plt.figure(figsize=(12,12))
plt.imshow(imgs.permute(1,2,0));

# %%
#Import CNN from scratch
class Net(nn.Module):
    def __init__(self,out,kernel):
        super().__init__()
        self.conv1 = nn.Conv2d(1,out,kernel,padding=1)
        self.bn1 = nn.BatchNorm2d(out)
        self.conv2 = nn.Conv2d(out,out,kernel,padding=1)
        self.bn2 = nn.BatchNorm2d(out)
        self.pool1 = nn.AdaptiveMaxPool2d(1)
        self.pool2 = nn.AdaptiveAvgPool2d(1)
        self.lin1 = nn.Linear(out*2,out)
        self.bn = nn.BatchNorm1d(out)
        self.lin2 = nn.Linear(out,10)
    def forward(self,x):
        x = self.bn1(F.relu_(self.conv1(x)))
        x = self.bn2(F.relu_(self.conv2(x)))
        p1 = self.pool1(x)
        p2 = self.pool2(x)
        x = torch.cat((p1,p2),dim=1)
        x = x.view(x.size(0),-1)
        x = self.bn(F.relu(self.lin1(x)))
        x = self.lin2(x)
        return x

# %%
def get_correct_num(predict,label):
    correct = torch.argmax(predict.softmax(dim=1),dim=1).eq(label)
    return correct.sum().item()

def learn(net,data,epochs,lr=1e-3):
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(net.parameters(),lr=lr)
    total_losses = []
    total_accuracy = []
    for epoch in range(1,epochs+1):
        e_loss = 0
        correct = 0
        for batch in data:
            optimizer.zero_grad()
            img,label = batch
            if torch.cuda.is_available(): img,label=img.to(device),label.to(device)
            output = net(img)
            loss = criterion(output,label)
            loss.backward()
            optimizer.step()
            e_loss += loss.item()
            correct += get_correct_num(output,label)
        e_acc = round(correct/(len(data)*data.batch_size)*100,5)
        print('''Epoch:{} Training Loss {} Training Accuracy {}%
              '''.format(epoch,e_loss,e_acc))
        total_losses.append(e_loss)
        total_accuracy.append(e_acc)
    return total_losses,total_accuracy

# %%
class runner():
    def __init__(self,out_channels,kernel_size,data,epochs,lr=1e-3):
        self.out_channels = out_channels
        self.kernel_size = kernel_size
        self.data = data
        self.epochs = epochs
        self.lr = lr
    def run(self):
        self.net = Net(self.out_channels,self.kernel_size).to(device)
        l,a = learn(self.net,self.data,self.epochs,self.lr)
        
        fig, ax1 = plt.subplots()
        color = 'tab:red'
        ax1.set_xlabel('lr={} out_channels={} kernel={}'.format(
            self.lr,self.out_channels,self.kernel_size))
        ax1.set_ylabel('losses', color=color)
        ax1.plot(l, color=color)
        ax1.tick_params(axis='y', labelcolor=color)
        ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
        color = 'tab:blue'
        ax2.set_ylabel('accuracy', color=color)  # we already handled the x-label with ax1
        ax2.plot(a, color=color)
        ax2.tick_params(axis='y', labelcolor=color)
        fig.tight_layout()

# %%
# Lets create a small dataloader to overfit the model with
# before introducing the full dataset
# Define sampling method

weights= 100/(torch.bincount(trns.targets).double())
weighted = torch.utils.data.WeightedRandomSampler(weights,num_samples=100
                                               ,replacement=True)
random = torch.utils.data.RandomSampler(trns,replacement=True,num_samples=100)

#After trying many different sampling methods i went with random because it gave the most balanced results
dl_small= torch.utils.data.DataLoader(trns,batch_size=100,sampler=random)

xs,ys = next(iter(dl_small))
# print(sorted(Counter(ys.numpy()).items()))

# %%
r = runner(512,7,dl_small,100,lr=1e-4)
r.run()
# Out:
# Epoch:1 Training Loss 2.3618552684783936 Training Accuracy 11.0%
#
# Epoch:2 Training Loss 1.531070590019226 Training Accuracy 62.0%
#
# Epoch:3 Training Loss 1.150786280632019 Training Accuracy 73.0%
#
# Epoch:4 Training Loss 1.0454500913619995 Training Accuracy 79.0%
#
# Epoch:5 Training Loss 0.9560673236846924 Training Accuracy 81.0%
#
# Epoch:6 Training Loss 0.7964416742324829 Training Accuracy 83.0%
#
# Epoch:7 Training Loss 0.7245584726333618 Training Accuracy 86.0%
#
# Epoch:8 Training Loss 0.5908414721488953 Training Accuracy 92.0%
#
# Epoch:9 Training Loss 0.6385509967803955 Training Accuracy 85.0%
#
# Epoch:10 Training Loss 0.672282338142395 Training Accuracy 84.0%
#
# Epoch:11 Training Loss 0.48021966218948364 Training Accuracy 95.0%
#
# Epoch:12 Training Loss 0.5717495083808899 Training Accuracy 90.0%
#
# Epoch:13 Training Loss 0.5458411574363708 Training Accuracy 94.0%
#
# Epoch:14 Training Loss 0.5037873387336731 Training Accuracy 92.0%
#
# Epoch:15 Training Loss 0.4172704815864563 Training Accuracy 95.0%
#
# Epoch:16 Training Loss 0.39057686924934387 Training Accuracy 96.0%
#
# Epoch:17 Training Loss 0.496139258146286 Training Accuracy 91.0%
#
# Epoch:18 Training Loss 0.3452102243900299 Training Accuracy 95.0%
#
# Epoch:19 Training Loss 0.3594219982624054 Training Accuracy 96.0%
#
# Epoch:20 Training Loss 0.3224595785140991 Training Accuracy 94.0%
#
# Epoch:21 Training Loss 0.2822187840938568 Training Accuracy 96.0%
#
# Epoch:22 Training Loss 0.40790215134620667 Training Accuracy 91.0%
#
# Epoch:23 Training Loss 0.3428340256214142 Training Accuracy 96.0%
#
# Epoch:24 Training Loss 0.2783811390399933 Training Accuracy 96.0%
#
# Epoch:25 Training Loss 0.24202676117420197 Training Accuracy 97.0%
#
# Epoch:26 Training Loss 0.3176647126674652 Training Accuracy 93.0%
#
# Epoch:27 Training Loss 0.2159101366996765 Training Accuracy 98.0%
#
# Epoch:28 Training Loss 0.2667187750339508 Training Accuracy 95.0%
#
# Epoch:29 Training Loss 0.36426788568496704 Training Accuracy 91.0%
#
# Epoch:30 Training Loss 0.22890909016132355 Training Accuracy 96.0%
#
# Epoch:31 Training Loss 0.24344606697559357 Training Accuracy 95.0%
#
# Epoch:32 Training Loss 0.17568464577198029 Training Accuracy 99.0%
#
# Epoch:33 Training Loss 0.21547365188598633 Training Accuracy 98.0%
#
# Epoch:34 Training Loss 0.2253001630306244 Training Accuracy 94.0%
#
# Epoch:35 Training Loss 0.252602219581604 Training Accuracy 94.0%
#
# Epoch:36 Training Loss 0.20207546651363373 Training Accuracy 97.0%
#
# Epoch:37 Training Loss 0.2338770478963852 Training Accuracy 96.0%
#
# Epoch:38 Training Loss 0.230286106467247 Training Accuracy 95.0%
#
# Epoch:39 Training Loss 0.18299011886119843 Training Accuracy 99.0%
#
# Epoch:40 Training Loss 0.18372748792171478 Training Accuracy 97.0%
#
# Epoch:41 Training Loss 0.16950945556163788 Training Accuracy 96.0%
#
# Epoch:42 Training Loss 0.21646758913993835 Training Accuracy 95.0%
#
# Epoch:43 Training Loss 0.2552657723426819 Training Accuracy 94.0%
#
# Epoch:44 Training Loss 0.17862144112586975 Training Accuracy 95.0%
#
# Epoch:45 Training Loss 0.1603306382894516 Training Accuracy 98.0%
#
# Epoch:46 Training Loss 0.16695113480091095 Training Accuracy 98.0%
#
# Epoch:47 Training Loss 0.15317200124263763 Training Accuracy 99.0%
#
# Epoch:48 Training Loss 0.1872534155845642 Training Accuracy 96.0%
#
# Epoch:49 Training Loss 0.2344481498003006 Training Accuracy 95.0%
#
# Epoch:50 Training Loss 0.2444273829460144 Training Accuracy 94.0%
#
# Epoch:51 Training Loss 0.20293183624744415 Training Accuracy 96.0%
#
# Epoch:52 Training Loss 0.1598295420408249 Training Accuracy 97.0%
#
# Epoch:53 Training Loss 0.16041886806488037 Training Accuracy 97.0%
#
# Epoch:54 Training Loss 0.12830153107643127 Training Accuracy 100.0%
#
# Epoch:55 Training Loss 0.1448562890291214 Training Accuracy 99.0%
#
# Epoch:56 Training Loss 0.18017885088920593 Training Accuracy 96.0%
#
# Epoch:57 Training Loss 0.12205896526575089 Training Accuracy 100.0%
#
# Epoch:58 Training Loss 0.13957148790359497 Training Accuracy 99.0%
#
# Epoch:59 Training Loss 0.16708679497241974 Training Accuracy 96.0%
#
# Epoch:60 Training Loss 0.12259814888238907 Training Accuracy 99.0%
#
# Epoch:61 Training Loss 0.11955335736274719 Training Accuracy 98.0%
#
# Epoch:62 Training Loss 0.13900890946388245 Training Accuracy 98.0%
#
# Epoch:63 Training Loss 0.2309255748987198 Training Accuracy 95.0%
#
# Epoch:64 Training Loss 0.19522446393966675 Training Accuracy 97.0%
#
# Epoch:65 Training Loss 0.15310534834861755 Training Accuracy 96.0%
#
# Epoch:66 Training Loss 0.09809260070323944 Training Accuracy 99.0%
#
# Epoch:67 Training Loss 0.1220971941947937 Training Accuracy 97.0%
#
# Epoch:68 Training Loss 0.11441566795110703 Training Accuracy 98.0%
#
# Epoch:69 Training Loss 0.13499175012111664 Training Accuracy 99.0%
#
# Epoch:70 Training Loss 0.0976836085319519 Training Accuracy 99.0%
#
# Epoch:71 Training Loss 0.10194989293813705 Training Accuracy 99.0%
#
# Epoch:72 Training Loss 0.19191618263721466 Training Accuracy 94.0%
#
# Epoch:73 Training Loss 0.19317400455474854 Training Accuracy 97.0%
#
# Epoch:74 Training Loss 0.2003786265850067 Training Accuracy 97.0%
#
# Epoch:75 Training Loss 0.12300331890583038 Training Accuracy 99.0%
#
# Epoch:76 Training Loss 0.09506934881210327 Training Accuracy 99.0%
#
# Epoch:77 Training Loss 0.11893642693758011 Training Accuracy 98.0%
#
# Epoch:78 Training Loss 0.15837885439395905 Training Accuracy 94.0%
#
# Epoch:79 Training Loss 0.0885460302233696 Training Accuracy 98.0%
#
# Epoch:80 Training Loss 0.1284281313419342 Training Accuracy 99.0%
#
# Epoch:81 Training Loss 0.15487025678157806 Training Accuracy 97.0%
#
# Epoch:82 Training Loss 0.18435785174369812 Training Accuracy 96.0%
#
# Epoch:83 Training Loss 0.15211617946624756 Training Accuracy 95.0%
#
# Epoch:84 Training Loss 0.10049144923686981 Training Accuracy 99.0%
#
# Epoch:85 Training Loss 0.12171956896781921 Training Accuracy 97.0%
#
# Epoch:86 Training Loss 0.09563783556222916 Training Accuracy 97.0%
#
# Epoch:87 Training Loss 0.10377734899520874 Training Accuracy 99.0%
#
# Epoch:88 Training Loss 0.14825032651424408 Training Accuracy 97.0%
#
# Epoch:89 Training Loss 0.10350780189037323 Training Accuracy 97.0%
#
# Epoch:90 Training Loss 0.13536226749420166 Training Accuracy 97.0%
#
# Epoch:91 Training Loss 0.16241389513015747 Training Accuracy 96.0%
#
# Epoch:92 Training Loss 0.10104485601186752 Training Accuracy 98.0%
#
# Epoch:93 Training Loss 0.0694798082113266 Training Accuracy 99.0%
#
# Epoch:94 Training Loss 0.08456511795520782 Training Accuracy 99.0%
#
# Epoch:95 Training Loss 0.15773235261440277 Training Accuracy 96.0%
#
# Epoch:96 Training Loss 0.17960186302661896 Training Accuracy 95.0%
#
# Epoch:97 Training Loss 0.08826208859682083 Training Accuracy 97.0%
#
# Epoch:98 Training Loss 0.10159553587436676 Training Accuracy 99.0%
#
# Epoch:99 Training Loss 0.09154418855905533 Training Accuracy 98.0%
#
# Epoch:100 Training Loss 0.1332467794418335 Training Accuracy 96.0%

# %%
t = runner(512,7,train,5,lr=1e-4);
t.run()
# Out:
# Epoch:1 Training Loss 55.59594931732863 Training Accuracy 97.742%
#
# Epoch:2 Training Loss 16.414344095159322 Training Accuracy 99.27%
#
# Epoch:3 Training Loss 8.588355074869469 Training Accuracy 99.7%
#
# Epoch:4 Training Loss 5.165852250531316 Training Accuracy 99.852%
#
# Epoch:5 Training Loss 3.8411565523128957 Training Accuracy 99.908%

# %%
@torch.no_grad()
def predict_all(net,loader):
    predict = torch.tensor([]).to(device)
    labels = torch.tensor([]).int().to(device)
    for img,label in loader:
        if torch.cuda.is_available(): img,label=img.to(device),label.to(device)
        p=net(img)
        predict = torch.cat((predict,p),dim=0)
        labels = torch.cat((labels,label.int()),dim=0)
    return predict,labels

# %%
p,l = predict_all(r.net,valid)

# %%
get_correct_num(p,l)/len(p)
# Out:
# 0.98075
